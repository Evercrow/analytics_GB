# %% [markdown]
# #### Задача 1
# 1. Скачать данные по ссылке
# https://www.kaggle.com/datasets/ionaskel/laptop-prices
# 2. Считать данные с помощью pandas
# 3. Вывести на экран первые 5 строк
# 4. Посмотреть на описание признаков и на их содержание

# %%
import pandas as pd

a = pd.read_csv('./laptops.csv',encoding='ISO-8859-1',index_col=[0])
a
# Out:
#      Company                              Product            TypeName  Inches  \
# 1      Apple                          MacBook Pro           Ultrabook    13.3
# 2      Apple                          Macbook Air           Ultrabook    13.3
# 3         HP                               250 G6            Notebook    15.6
# 4      Apple                          MacBook Pro           Ultrabook    15.4
# 5      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1316  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1317  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1318  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 1             IPS Panel Retina Display 2560x1600
# 2                                       1440x900
# 3                              Full HD 1920x1080
# 4             IPS Panel Retina Display 2880x1800
# 5             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1316   IPS Panel Full HD / Touchscreen 1920x1080
# 1317  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318                                    1366x768
# 1319                                    1366x768
# 1320                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 1                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1316            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1317            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1318  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1319            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1320  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 1     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3            Intel HD Graphics 620       No OS  1.86kg       575.00
# 4               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1316         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1317         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1318             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1319            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1320             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %%
a.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           3      HP       250 G6   Notebook    15.6
# 3           4   Apple  MacBook Pro  Ultrabook    15.4
# 4           5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
a=a.drop(columns=['Unnamed: 0'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 a=a.drop(columns=['Unnamed: 0'])
#       2 a
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\frame.py:4957, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4809 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4810 def drop(
#    4811     self,
#    (...)
#    4818     errors: str = "raise",
#    4819 ):
#    4820     """
#    4821     Drop specified labels from rows or columns.
#    4822
#    (...)
#    4955             weight  1.0     0.8
#    4956     """
# -> 4957     return super().drop(
#    4958         labels=labels,
#    4959         axis=axis,
#    4960         index=index,
#    4961         columns=columns,
#    4962         level=level,
#    4963         inplace=inplace,
#    4964         errors=errors,
#    4965     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4267, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265 for axis, labels in axes.items():
#    4266     if labels is not None:
# -> 4267         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4269 if inplace:
#    4270     self._update_inplace(obj)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\generic.py:4311, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309         new_axis = axis.drop(labels, level=level, errors=errors)
#    4310     else:
# -> 4311         new_axis = axis.drop(labels, errors=errors)
#    4312     indexer = axis.get_indexer(new_axis)
#    4314 # Case for non-unique axis
#    4315 else:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\pandas\core\indexes\base.py:6661, in Index.drop(self, labels, errors)
#    6659 if mask.any():
#    6660     if errors != "ignore":
# -> 6661         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662     indexer = indexer[~mask]
#    6663 return self.delete(indexer)
#
# KeyError: "['Unnamed: 0'] not found in axis"

# %% [markdown]
# #### Проведите первичный анализ данных
# 1. Изучите типы данных
# 2. Найдите количество пропущенных ячеек в данных
# 3. Посчитайте основные статистики по всем признакам и поизучайте их

# %%
import pandas as pd

a = pd.read_csv('./laptops.csv',encoding='ISO-8859-1',index_col=[0])
a
# Out:
#      Company                              Product            TypeName  Inches  \
# 1      Apple                          MacBook Pro           Ultrabook    13.3
# 2      Apple                          Macbook Air           Ultrabook    13.3
# 3         HP                               250 G6            Notebook    15.6
# 4      Apple                          MacBook Pro           Ultrabook    15.4
# 5      Apple                          MacBook Pro           Ultrabook    13.3
# ...      ...                                  ...                 ...     ...
# 1316  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1317  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1318  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 1             IPS Panel Retina Display 2560x1600
# 2                                       1440x900
# 3                              Full HD 1920x1080
# 4             IPS Panel Retina Display 2880x1800
# 5             IPS Panel Retina Display 2560x1600
# ...                                          ...
# 1316   IPS Panel Full HD / Touchscreen 1920x1080
# 1317  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1318                                    1366x768
# 1319                                    1366x768
# 1320                                    1366x768
#
#                                        Cpu   Ram               Memory  \
# 1                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 2                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 3               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 4                     Intel Core i7 2.7GHz  16GB            512GB SSD
# 5                     Intel Core i5 3.1GHz   8GB            256GB SSD
# ...                                    ...   ...                  ...
# 1316            Intel Core i7 6500U 2.5GHz   4GB            128GB SSD
# 1317            Intel Core i7 6500U 2.5GHz  16GB            512GB SSD
# 1318  Intel Celeron Dual Core N3050 1.6GHz   2GB   64GB Flash Storage
# 1319            Intel Core i7 6500U 2.5GHz   6GB              1TB HDD
# 1320  Intel Celeron Dual Core N3050 1.6GHz   4GB            500GB HDD
#
#                                Gpu       OpSys  Weight  Price_euros
# 1     Intel Iris Plus Graphics 640       macOS  1.37kg      1339.69
# 2           Intel HD Graphics 6000       macOS  1.34kg       898.94
# 3            Intel HD Graphics 620       No OS  1.86kg       575.00
# 4               AMD Radeon Pro 455       macOS  1.83kg      2537.45
# 5     Intel Iris Plus Graphics 650       macOS  1.37kg      1803.60
# ...                            ...         ...     ...          ...
# 1316         Intel HD Graphics 520  Windows 10   1.8kg       638.00
# 1317         Intel HD Graphics 520  Windows 10   1.3kg      1499.00
# 1318             Intel HD Graphics  Windows 10   1.5kg       229.00
# 1319            AMD Radeon R5 M330  Windows 10  2.19kg       764.00
# 1320             Intel HD Graphics  Windows 10   2.2kg       369.00
#
# [1303 rows x 12 columns]

# %%
a.isnull().sum()
#посчитаем количество где True =null

# %%
a.isna().sum()
#посчитаем количество где NaN =null
# Out:
# Company             0
# Product             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price_euros         0
# dtype: int64

# %%
a.describe()
# Out:
#             Inches  Price_euros
# count  1303.000000  1303.000000
# mean     15.017191  1123.686992
# std       1.426304   699.009043
# min      10.100000   174.000000
# 25%      14.000000   599.000000
# 50%      15.600000   977.000000
# 75%      15.600000  1487.880000
# max      18.400000  6099.000000

# %% [markdown]
# 3.1 Ноутбуков от какой компании больше всего в наборе данных?

# %%
most_notebooks = a["Company"].value_counts()
most_notebooks
# Out:
# Dell         297
# Lenovo       297
# HP           274
# Asus         158
# Acer         103
# MSI           54
# Toshiba       48
# Apple         21
# Samsung        9
# Razer          7
# Mediacom       7
# Microsoft      6
# Xiaomi         4
# Vero           4
# Chuwi          3
# Google         3
# Fujitsu        3
# LG             3
# Huawei         2
# Name: Company, dtype: int64

# %%
most_notebooks.head(2)
#подходят две компании

# %% [markdown]
# 3. 2 Какая минимальная и максимальная стоимость у ноутбуков в данных?

# %%
a["Price_euros"].max()
# Out:
# 6099.0

# %%
a["Price_euros"].min()
# Out:
# 174.0

# %% [markdown]
# 3. 3 Какой самый дорогой ноутбук в данных?
# Выведите все характеристики только по этому ноутбуку
# Если таких ноутбуков несколько, то выводите их всех

# %%
a[a["Price_euros"] == a["Price_euros"].max()]
# Out:
#     Company    Product TypeName  Inches                     ScreenResolution  \
# 200   Razer  Blade Pro   Gaming    17.3  4K Ultra HD / Touchscreen 3840x2160
#
#                              Cpu   Ram   Memory                      Gpu  \
# 200  Intel Core i7 7820HK 2.9GHz  32GB  1TB SSD  Nvidia GeForce GTX 1080
#
#           OpSys  Weight  Price_euros
# 200  Windows 10  3.49kg       6099.0

# %%
a.sort_values("Price_euros",ascending=False).head()
#дубликатов нет по цене

# %% [markdown]
# Задание 4.
# Ответьте на несколько вопросов
# 4.1 Найдите ноутбуки с самой маленькой диагональю в данных?
# Выведите только следующие характеристики:
# 1. Компания
# 2. Типа ноутбука 3. Диагональ
# 4. Стоимость
# Если таких ноутбуков несколько, то выводите их всех

# %%
a_inches = a[a["Inches"] == a["Inches"].min()]
a_inches[["Company","TypeName","Inches","Price_euros"]]
# Out:
#      Company            TypeName  Inches  Price_euros
# 51    Lenovo  2 in 1 Convertible    10.1       319.00
# 1097  Lenovo  2 in 1 Convertible    10.1       646.27
# 1129  Lenovo  2 in 1 Convertible    10.1       549.00
# 1141  Lenovo  2 in 1 Convertible    10.1       479.00

# %% [markdown]
# #### 4.2 Сколько стоит самый дорогой ноутбук у компании HP?

# %%
max_hp = a[a['Company']=='HP']['Price_euros'].max()
a[a['Price_euros'] == max_hp]
# Out:
#     Company   Product     TypeName  Inches             ScreenResolution  \
# 758      HP  Zbook 17  Workstation    17.3  IPS Panel Full HD 1920x1080
#
#                                Cpu   Ram     Memory                   Gpu  \
# 758  Intel Xeon E3-1535M v5 2.9GHz  16GB  256GB SSD  Nvidia Quadro M2000M
#
#          OpSys Weight  Price_euros
# 758  Windows 7    3kg       4389.0

# %% [markdown]
# ### 4.3 Как много ноутбуков Ultrabook с 8GB RAM?
# Найдите сколько таких ультрабуков с 8GB ОЗУ в процентном соотношении относительно всех ультрабуков

# %%
ultra_df = a[(a['TypeName'] == 'Ultrabook')]
# (a['Ram'] == '8GB')
ultra_df['Ram'].value_counts(normalize=True)
# Out:
# 8GB     0.714286
# 16GB    0.183673
# 4GB     0.071429
# 12GB    0.015306
# 24GB    0.005102
# 32GB    0.005102
# 6GB     0.005102
# Name: Ram, dtype: float64

# %% [markdown]
# ### Задание 5.
# + 5.1 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук с 8GB или 16GB ОЗУ на Windows 10 в стоимости до 500 евро, сколько у него вариантов?
# + 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?
# + 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %% [markdown]
# #### 5.1 Выберите ноутбук клиенту

# %%
client_note = a[(a['Ram'].isin(['8GB','16GB'])) & (a['OpSys']== 'Windows 10') & (a['Price_euros'] <= 500)]
client_note.count()
# Out:
# Company             13
# Product             13
# TypeName            13
# Inches              13
# ScreenResolution    13
# Cpu                 13
# Ram                 13
# Memory              13
# Gpu                 13
# OpSys               13
# Weight              13
# Price_euros         13
# dtype: int64

# %%
client_note
# Out:
#      Company                                   Product  TypeName  Inches  \
# 76      Acer                             Aspire E5-475  Notebook    14.0
# 179     Dell                             Inspiron 3567  Notebook    15.6
# 261       HP        15-BW094nd (A6-9220/8GB/128GB/W10)  Notebook    15.6
# 297       HP         17-BS037cl (i3-6006U/8GB/1TB/W10)  Notebook    17.3
# 318     Acer  ES1-523-84K7 (A8-7410/8GB/256GB/FHD/W10)  Notebook    15.6
# 371       HP            15-AY023na (N3710/8GB/2TB/W10)  Notebook    15.6
# 578       HP            14-am079na (N3710/8GB/2TB/W10)  Notebook    14.0
# 602   Lenovo                         IdeaPad 110-15ISK  Notebook    15.6
# 642     Asus         X541NA-GO414T (N3350/8GB/1TB/W10)  Notebook    15.6
# 710   Lenovo                         IdeaPad 320-15ABR  Notebook    15.6
# 1071    Acer                            Aspire ES1-523  Notebook    15.6
# 1181  Lenovo                         IdeaPad 310-15ISK  Notebook    15.6
# 1250    Dell                             Inspiron 3567  Notebook    15.6
#
#           ScreenResolution                                   Cpu  Ram  \
# 76                1366x768              Intel Core i3 6006U 2GHz  8GB
# 179               1366x768            Intel Core i3 7100U 2.4GHz  8GB
# 261               1366x768          AMD A6-Series A6-9220 2.5GHz  8GB
# 297               1600x900              Intel Core i3 6006U 2GHz  8GB
# 318      Full HD 1920x1080             AMD A8-Series 7410 2.2GHz  8GB
# 371               1366x768  Intel Pentium Quad Core N3710 1.6GHz  8GB
# 578               1366x768  Intel Pentium Quad Core N3710 1.6GHz  8GB
# 602               1366x768            Intel Core i3 6100U 2.3GHz  8GB
# 642               1366x768  Intel Celeron Dual Core N3350 1.1GHz  8GB
# 710               1366x768           AMD A12-Series 9720P 3.6GHz  8GB
# 1071              1366x768             AMD A8-Series 7410 2.2GHz  8GB
# 1181              1366x768            Intel Core i3 6006U 2.0GHz  8GB
# 1250  Touchscreen 1366x768            Intel Core i3 7100U 2.4GHz  8GB
#
#          Memory                     Gpu       OpSys  Weight  Price_euros
# 76      1TB HDD   Intel HD Graphics 520  Windows 10   2.1kg       389.00
# 179     1TB HDD   Intel HD Graphics 620  Windows 10   2.3kg       459.00
# 261   128GB SSD  AMD Radeon R4 Graphics  Windows 10  1.91kg       445.90
# 297     1TB HDD   Intel HD Graphics 520  Windows 10  2.54kg       489.00
# 318   256GB SSD           AMD Radeon R5  Windows 10  2.23kg       469.00
# 371     2TB HDD   Intel HD Graphics 405  Windows 10  2.04kg       389.00
# 578     2TB HDD   Intel HD Graphics 405  Windows 10  1.94kg       389.00
# 602     1TB HDD   Intel HD Graphics 520  Windows 10  2.29kg       459.00
# 642     1TB HDD   Intel HD Graphics 500  Windows 10     2kg       399.00
# 710     1TB HDD           AMD Radeon R7  Windows 10   2.2kg       429.00
# 1071    1TB HDD           AMD Radeon R5  Windows 10   2.4kg       449.00
# 1181    1TB HDD   Intel HD Graphics 520  Windows 10   2.2kg       459.00
# 1250    1TB HDD   Intel HD Graphics 620  Windows 10   2.3kg       469.01

# %% [markdown]
# 5.2 Выберите ноутбук клиенту
# Клиент хочет подобрать ноутбук от MSI, с видеокартой Nvidia GeForce GTX 1050 Ti и главное не с диагональю 15.6. В какой ценовой категории вышли подобные ноутбуки?

# %%
client_note2 = a[(a['Company']=='MSI') & (a['Gpu']== 'Nvidia GeForce GTX 1050 Ti') & (a['Inches'] != 15.6)]
client_note2['Price_euros'].max()
def WhatPriceCat(price: float, total_pr : pd.DataFrame) ->str:
    if price >= total_pr.quantile(0.75):
        return "Ноутбуки находятся в премиальном сегменте"
    elif price >= total_pr.quantile(0.5):
        return "Ноутбуки находятся в дорогом ценовом сегменте"
    elif price >= total_pr.quantile(0.25):
        return "Ноутбуки находятся в бюджетном ценовом сегменте"
    else: return "Ноутбуки находятся в дешевом ценовом сегменте"

top_price = client_note2['Price_euros'].max()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [2], line 1
# ----> 1 client_note2 = a[(a['Company']=='MSI') & (a['Gpu']== 'Nvidia GeForce GTX 1050 Ti') & (a['Inches'] != 15.6)]
#       2 client_note2['Price_euros'].max()
#       3 def WhatPriceCat(price: float, total_pr : pd.DataFrame) ->str:
#
# NameError: name 'a' is not defined

# %%
bottom_price = client_note2['Price_euros'].min()
WhatPriceCat(bottom_price,client_note2['Price_euros'])
# Out:
# 'Ноутбуки находятся в дешевом ценовом сегменте'

# %%
client_note2['Price_euros'].describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [13], line 1
# ----> 1 client_note2['Price_euros'].describe()
#
# NameError: name 'client_note2' is not defined

# %% [markdown]
# + 5.3 Что дешевле?
# В среднем дешевле ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz или с Intel Core i7 7600U 2.8GHz?

# %%
if (a[a['Cpu']=='Intel Core i7 7700HQ 2.8GHz']['Price_euros'].mean() 
        > a[a['Cpu']=='Intel Core i7 7600U 2.8GHz']['Price_euros'].mean()):
    print('ноутбуки с Intel Core i7 7600U 2.8GHz в среднем дешевле')
else : print('ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz в среднем дешевле')
# a.columns
# Out:
# ноутбуки с CPU Intel Core i7 7700HQ 2.8GHz в среднем дешевле

# %% [markdown]
# ### Задание 6.
# Найдите самый легкий ноутбук
# Но обратите внимание на тип и представление данных в признаке Weight, если что, замените в строке 'kg' на пустую строку через метод .str.replace()

# %%
#отфильтруем только ноутбуки и сортируем по весу
weighted = a[a['TypeName'] == 'Notebook' ].sort_values('Weight')
weighted = weighted[['Product','Weight','Price_euros','Company']]
weighted.head(10)
# Out:
#                         Product  Weight  Price_euros  Company
# 906           Portege X30-D-10V  1.05kg      1475.00  Toshiba
# 873           Portege X30-D-10X  1.05kg      1285.00  Toshiba
# 486           Portege X30-D-10J  1.05kg      1672.00  Toshiba
# 1036          Spectre 13-V100nv  1.11kg      1149.00       HP
# 416              Lenovo IdeaPad  1.15kg       304.45   Lenovo
# 1125             EliteBook 1030  1.16kg      1699.00       HP
# 1136                Spectre Pro  1.16kg      1690.00       HP
# 1064                ThinkPad X1   1.1kg      2620.00   Lenovo
# 315          IdeaPad 720S-13IKB   1.1kg       999.00   Lenovo
# 800   K146 (N3350/4GB/32GB/W10)  1.22kg       202.90     Vero

# %%
#находим самую легкую модель/модели
weighted[weighted['Weight']==weighted['Weight'].min()]
# Out:
#                Product  Weight  Price_euros  Company
# 906  Portege X30-D-10V  1.05kg       1475.0  Toshiba
# 873  Portege X30-D-10X  1.05kg       1285.0  Toshiba
# 486  Portege X30-D-10J  1.05kg       1672.0  Toshiba

# %%
weighted['Weight']= weighted['Weight'].str.replace('kg','')
weighted
# Out:
#                 Product Weight  Price_euros  Company
# 906   Portege X30-D-10V   1.05      1475.00  Toshiba
# 873   Portege X30-D-10X   1.05      1285.00  Toshiba
# 486   Portege X30-D-10J   1.05      1672.00  Toshiba
# 1036  Spectre 13-V100nv   1.11      1149.00       HP
# 416      Lenovo IdeaPad   1.15       304.45   Lenovo
# ...                 ...    ...          ...      ...
# 172     Aspire A517-51G      3       854.00     Acer
# 289     Aspire A517-51G      3       951.00     Acer
# 259            Aspire 5      3       702.00     Acer
# 143            Aspire 5      3       655.00     Acer
# 463        Alienware 17   4.42      2046.00     Dell
#
# [727 rows x 4 columns]
